# %% [markdown]
# # Transition-state acceptance logic
#
# Built with [Vicena](https://vicena.ai). This notebook reads archived or synthetic outputs only and never submits Rowan jobs.

# %%
from pathlib import Path
import sys, json
ROOT=Path.cwd().parent if Path.cwd().name=="notebooks" else Path.cwd()
sys.path.insert(0,str(ROOT/"src"))
from reaction_mechanism_twin import *
r=load(ROOT/"results/example/archived_result.json")
print(json.dumps(accept_ts(r),indent=2))
print("Convergence alone is not chemical validity.")
# Out:
# {
#   "accepted": true,
#   "checks": {
#     "one_relevant_imaginary": true,
#     "mapping": true,
#     "geometry": true,
#     "irc_backward": true,
#     "irc_forward": true
#   },
#   "imaginary_count": 1
# }
# Convergence alone is not chemical validity.
