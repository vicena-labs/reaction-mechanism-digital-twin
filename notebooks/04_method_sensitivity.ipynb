# %% [markdown]
# # Method sensitivity and uncertainty
#
# Built with [Vicena](https://vicena.ai). This notebook reads archived or synthetic outputs only and never submits Rowan jobs.

# %%
from pathlib import Path
import sys, json
ROOT=Path.cwd().parent if Path.cwd().name=="notebooks" else Path.cwd()
sys.path.insert(0,str(ROOT/"src"))
from reaction_mechanism_twin import *
r=load(ROOT/"results/example/archived_result.json")
import pandas as pd
s=pd.Series(r["method_sensitivity_kcal_mol"],name="activation_kcal_mol");display(s.to_frame());print("range",s.min(),s.max(),"kcal/mol")
# Out:
#                 activation_kcal_mol
# illustrative_A                 27.0
# illustrative_B                 29.5
# illustrative_C                 24.8
# range 24.8 29.5 kcal/mol
