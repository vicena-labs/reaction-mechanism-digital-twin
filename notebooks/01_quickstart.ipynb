# %% [markdown]
# # Quickstart archived analysis
#
# Built with [Vicena](https://vicena.ai). This notebook reads archived or synthetic outputs only and never submits Rowan jobs.

# %%
from pathlib import Path
import sys, json
ROOT=Path.cwd().parent if Path.cwd().name=="notebooks" else Path.cwd()
sys.path.insert(0,str(ROOT/"src"))
from reaction_mechanism_twin import *
r=load(ROOT/"results/example/archived_result.json")
print(validate(load(ROOT/"reactions/example/reaction.json")))
print(energetics(r)); print(accept_ts(r))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 7
#       3 ROOT=Path.cwd().parent if Path.cwd().name=="notebooks" else Path.cwd()
#       4 sys.path.insert(0,str(ROOT/"src"))
#       5 from reaction_mechanism_twin import *
#       6 r=load(ROOT/"results/example/archived_result.json")
# ----> 7 print(validate(load(ROOT/"reactions/example/reaction.json")))
#       8 print(energetics(r)); print(accept_ts(r))
#
# File ~/sessions/476_open-source-reaction-mechanism-twin/reaction-mechanism-digital-twin/src/reaction_mechanism_twin/core.py:9, in validate(m)
#       7 if sorted(a)!=sorted(b): raise ValueError('element conservation failed')
#       8 if sorted(m['atom_mapping'])!=list(range(1,len(a)+1)): raise ValueError('invalid mapping')
# ----> 9 if [b[i-1] for i in m['atom_mapping']]!=a: raise ValueError('mapping element mismatch')
#      10 if m['charge']!=sum(x['charge'] for x in m['reactants']) or m['charge']!=sum(x['charge'] for x in m['products']): raise ValueError('charge mismatch')
#      11 if any(x['multiplicity']!=m['multiplicity'] for x in m['reactants']+m['products']): raise ValueError('multiplicity mismatch')
#
# ValueError: mapping element mismatch
