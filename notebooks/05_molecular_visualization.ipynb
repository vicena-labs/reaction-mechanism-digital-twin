# %% [markdown]
# # 3Dmol endpoint and TS-proxy visualization
#
# Built with [Vicena](https://vicena.ai). This notebook reads archived or synthetic outputs only and never submits Rowan jobs.

# %%
from pathlib import Path
ROOT=Path.cwd().parent if Path.cwd().name=="notebooks" else Path.cwd()
print("Open native scene:",ROOT/"results/example/structures/reaction_path.molscene.json")
print("The TS object is a labeled visual proxy, not a calculated stationary point.")
# Out:
# Open native scene: /root/sessions/476_open-source-reaction-mechanism-twin/reaction-mechanism-digital-twin/results/example/structures/reaction_path.molscene.json
# The TS object is a labeled visual proxy, not a calculated stationary point.
