# %% [markdown]
# <p align="center">
#   <a href="https://vicena.ai"><strong>Built with Vicena</strong></a>
# </p>
#
# # Reaction Mechanism Analysis and Validation Starter overview
#
# This notebook regenerates the A4 landscape PDF and PNG using the Vicena Research Twins design system. It presents the repository as an analysis and validation starter, shows the eight-stage guided workflow, and labels the energy, frequency, and IRC examples as synthetic fixtures rather than computed mechanism results.

# %%
from pathlib import Path
from IPython.display import Image, display
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
# %run ../scripts/generate_branded_assets.py
pdf = ROOT / "Reaction_Mechanism_Analysis_Starter_OnePager.pdf"
png = ROOT / "assets/reaction-mechanism-analysis-starter-onepager.png"
print("PDF:", pdf)
print("PNG:", png)
print("Scientific status: analysis and validation starter, not an end-to-end mechanism solver")
display(Image(filename=str(png), width=1100))
# Out:
# Rowan workflow UUID: 3d530210-368d-4296-9460-94b383d7295a
# Rowan credits charged: 0.37
# Conformers returned: 1
# Archived fixture activation energy (kcal/mol): 26.999285379266144
# Generated reference-family PDF, PNG, reaction scheme, Rowan conformer, and archived profile
# PDF: /root/sessions/476_open-source-reaction-mechanism-twin/reaction-mechanism-digital-twin/Reaction_Mechanism_Analysis_Starter_OnePager.pdf
# PNG: /root/sessions/476_open-source-reaction-mechanism-twin/reaction-mechanism-digital-twin/assets/reaction-mechanism-analysis-starter-onepager.png
# Scientific status: analysis and validation starter, not an end-to-end mechanism solver
