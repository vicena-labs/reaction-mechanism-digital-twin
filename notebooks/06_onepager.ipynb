# %% [markdown]
# <p align="center">
#   <a href="https://vicena.ai"><strong>Built with Vicena</strong></a>
# </p>
#
# # Reaction Mechanism Digital Twin one-page overview
#
# This notebook regenerates the A4 landscape PDF and PNG using the Vicena Research Twins design system and actual saved repository results. The energy profile remains clearly labeled as a synthetic archived fixture.

# %%
from pathlib import Path
from IPython.display import Image, display
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
# %run ../scripts/generate_branded_assets.py
print("PDF:", ROOT / "Reaction_Mechanism_Digital_Twin_OnePager.pdf")
print("PNG:", ROOT / "assets/reaction-mechanism-digital-twin-onepager.png")
display(Image(filename=str(ROOT / "assets/reaction-mechanism-digital-twin-onepager.png"), width=1100))
# Out:
# Rowan workflow UUID: 3d530210-368d-4296-9460-94b383d7295a
# Rowan credits charged: 0.37
# Conformers returned: 1
# Archived fixture activation energy (kcal/mol): 26.999285379266144
# Generated branded PDF, PNG, reaction scheme, Rowan conformer, and archived profile assets
# PDF: /root/sessions/476_open-source-reaction-mechanism-twin/reaction-mechanism-digital-twin/Reaction_Mechanism_Digital_Twin_OnePager.pdf
# PNG: /root/sessions/476_open-source-reaction-mechanism-twin/reaction-mechanism-digital-twin/assets/reaction-mechanism-digital-twin-onepager.png
